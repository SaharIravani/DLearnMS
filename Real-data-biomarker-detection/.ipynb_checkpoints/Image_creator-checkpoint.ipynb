# %%
from pyopenms import *
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
from skimage import io
# Out:
# Determination of memory status is not supported on this
#  platform, measuring for memoryleaks will never fail

# %%
# def round_of_rating(number,rate):
#     return round(number * rate) / rate

# def find_nearest(array, value):
#     array = np.asarray(array)
#     idx = (np.abs(array - value)).argmin()
#     return idx

# def image_creator(filename_in):
#     RT_the_whole =[]
#     exp = MSExperiment()
#     MzMLFile().load(filename_in, exp)
#     mg = np.zeros((14000, 2000))
#     for  count, spec in enumerate(exp):
#         if count>0:
#             RT =spec.getRT()
#             if RT<6999 and spec.getMSLevel()==1:  
#                 mz, intensity = spec.get_peaks()
# #                 x = int(np.floor(RT)) 
#                 x= int(round_of_rating(RT,2)*)
#                 RT_the_whole.append(RT)
#                 for c, mz_ in enumerate(mz):
#                     if (mz_<999):
#                         y = int(round_of_rating(mz_,2)*2)
#                         #if intensity[c]>0.05:
#                         mg[x,y] = intensity[c]
#     #plt.imshow(mg,cmap="seismic",vmin=-8, vmax=8)
#     return mg, RT_the_whole

# direction = '/Users/siravani/Documents/LC-MSRealData/\
# Using a Spike-In Experiment to Evaluate Analysis of LC-MS Data/openms/\
# dta2d/50ugserum_MPrep_INCL_5ul240run_Subj4_inj1-s1.dta2d/'

# import glob
# files = glob.glob('*.mzML')
# import scipy.misc
# # for filename_in in files:
# #     image = image_creator(filename_in)
# #     #image = image.astype(np.uint8)
# #     #np.save(filename_in+'.png', image)
# #     io.imsave(filename_in+'.png', image)
# #filename_in = files[0]
# image1,RT_the_whole1 = image_creator(files[0])
# image2, RT_the_whole2 = image_creator(files[1])
# image3, RT_the_whole3 = image_creator(files[2])
# image4, RT_the_whole4 = image_creator(files[3])
# image5, RT_the_whole5 = image_creator(files[4])
# image6, RT_the_whole6 = image_creator(files[5])
# image7, RT_the_whole7 = image_creator(files[6])
# image8, RT_the_whole8 = image_creator(files[7])
# image9, RT_the_whole9 = image_creator(files[8])
# image10, RT_the_whole10= image_creator(files[9])

# %%
def round_of_rating(number,rate):
    return round(number * rate) / rate

round_of_rating(1.52,4)
# Out:
# 1.5

# %%
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

def image_creator(filename_in):
    RT_the_whole =[]
    X =[]
    count_seven_second = 0
    exp = MSExperiment()
    MzMLFile().load(filename_in, exp)
    mg = np.zeros((1000, 2000))
    for  count, spec in enumerate(exp):
        if count>0 and spec.getRT()<7999 and spec.getMSLevel()==1 :
            count_seven_second +=1
            RT =spec.getRT()
            mz, intensity = spec.get_peaks()
#             x = int(np.floor(RT)) 
            x= int(RT/10)
            RT_the_whole.append(RT)
            X.append(x)
            for c, mz_ in enumerate(mz):
                if (300<mz_<1299):
                    y = int(round_of_rating(mz_,2)*2)-600
                    #if intensity[c]>0.05:
                    mg[x,y] += intensity[c]

                        
            
    #plt.imshow(mg,cmap="seismic",vmin=-8, vmax=8)
    return mg, RT_the_whole, X

import glob
files = glob.glob('*.mzML')
import scipy.misc
# for filename_in in files:
#     image = image_creator(filename_in)
#     #image = image.astype(np.uint8)
#     #np.save(filename_in+'.png', image)
#     io.imsave(filename_in+'.png', image)
#filename_in = files[0]
image1,RT_the_whole1, X1 = image_creator(files[0])
image2, RT_the_whole2, X2= image_creator(files[1])
image3, RT_the_whole3, X3 = image_creator(files[2])
image4, RT_the_whole4, X4 = image_creator(files[3])
image5, RT_the_whole5, X5 = image_creator(files[4])
image6, RT_the_whole6, X6 = image_creator(files[5])
image7, RT_the_whole7, X7 = image_creator(files[6])
image8, RT_the_whole8, X8 = image_creator(files[7])
image9, RT_the_whole9, X9 = image_creator(files[8])
image10, RT_the_whole10, X10= image_creator(files[9])

# %%
files
# Out:
# ['50ugserum_MPrep_INCL_5ul240run_Subj1_inj1-s1.mzML',
#  '50ugserum_noMP_INCL_5ul240run_Subj1_inj1-s1.mzML',
#  '50ugserum_noMP_INCL_5ul240run_Subj3_inj1-s1.mzML',
#  '50ugserum_noMP_INCL_5ul240run_Subj4_inj1-s1.mzML',
#  '50ugserum_MPrep_INCL_5ul240run_Subj2_inj1-s1.mzML',
#  '50ugserum_MPrep_INCL_5ul240run_Subj5_inj1-s1.mzML',
#  '50ugserum_noMP_INCL_5ul240run_Subj5_inj1-s1.mzML',
#  '50ugserum_noMP_INCL_5ul240run_Subj2_inj1-s1.mzML',
#  '50ugserum_MPrep_INCL_5ul240run_Subj4_inj1-s1.mzML',
#  '50ugserum_MPrep_INCL_5ul240run_Subj3_inj1-s1.mzML']

# %%
path = '/Users/siravani/Documents/LC-MSRealData/Using a Spike-In Experiment to Evaluate Analysis of LC-MS Data/openms/mzml/TOPPAS_out/003-FileConverter-out/images_mz300-1300_RT140_rate_1/'

# %%
Images = [image1, image2, image3, image4, image5, image6, image7, image8, image9, image10 ]
Names = files
max_Images_intensity = np.max(Images)
Image_new=[]
for image, name in zip(Images, files):
    np.save( os.path.join( path,name), image)
    image = 255*(image/max_Images_intensity)
    image = image.astype(np.uint8)
    io.imsave(os.path.join(path,name+'.png'), image)
    Image_new.append(image)
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: /Users/siravani/Documents/LC-MSRealData/Using a Spike-In Experiment to Evaluate Analysis of LC-MS Data/openms/mzml/TOPPAS_out/003-FileConverter-out/images_mz300-1300_RT140_rate_1/50ugserum_MPrep_INCL_5ul240run_Subj1_inj1-s1.mzML.png is a low contrast image
#   if __name__ == '__main__':
# /opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: /Users/siravani/Documents/LC-MSRealData/Using a Spike-In Experiment to Evaluate Analysis of LC-MS Data/openms/mzml/TOPPAS_out/003-FileConverter-out/images_mz300-1300_RT140_rate_1/50ugserum_noMP_INCL_5ul240run_Subj1_inj1-s1.mzML.png is a low contrast image
#   if __name__ == '__main__':
# ...

# %%
Images_mp = [image1, image5, image6,   image9, image10]
RT_mp = [RT_the_whole1, RT_the_whole5,RT_the_whole6, RT_the_whole9 ,RT_the_whole10]
X_mp = [X1, X5, X6, X9, X10]
Images_nomp = [image2,image3, image4, image7, image8]
RT_nomp = [RT_the_whole2, RT_the_whole3,RT_the_whole4, RT_the_whole7,RT_the_whole8]
X_nomp = [X2, X3, X4,X7, X8]
np.shape(Images_mp)
# Out:
# (5, 1000, 2000)

# %%
def MZ_RT_min_max(filename_in):
    MZ_min=[]
    MZ_max=[]
    RT_the_whole =[]
    Nr_spectra=0
    exp = MSExperiment()
    MzMLFile().load(filename_in, exp)
    for  spec in exp:
        if spec.getMSLevel()==1 and spec.getRT()<6600:
            RT =spec.getRT()
            RT_the_whole.append(RT)
            Nr_spectra +=1
            mz, intensity = spec.get_peaks()
            if np.size(mz)!=0:
                MZ_min.append(min(mz))
                MZ_max.append(max(mz))
    return  min(RT_the_whole),max(RT_the_whole), min(MZ_min), max(MZ_max), Nr_spectra

# %%
MZ_RT_min_max(files[0])
# Out:
# (1.005, 6599.29, 350.0242919921875, 1997.4017333984375, 4176)

# %%
print('RT_min1, RT_max1 ,MZ_min1, MZ_max1 are, Number of Spectra: ')
print(files[0])
print( MZ_RT_min_max(files[0]))
print(files[1]) 
print( MZ_RT_min_max(files[1]))
print(files[2])
print( MZ_RT_min_max(files[2]))
print(files[3])
print( MZ_RT_min_max(files[3]))
print(files[4])
print( MZ_RT_min_max(files[4]))
print(files[5])
print(MZ_RT_min_max(files[5]))
print(files[6])
print( MZ_RT_min_max(files[6]))
print(files[7])
print( MZ_RT_min_max(files[7]))
print(files[8])
print( MZ_RT_min_max(files[8]))
print(files[9])
print( MZ_RT_min_max(files[9]))
# Out:
# RT_min1, RT_max1 ,MZ_min1, MZ_max1 are, Number of Spectra:
# 50ugserum_MPrep_INCL_5ul240run_Subj1_inj1-s1.mzML
# (1.005, 6599.29, 350.0242919921875, 1997.4017333984375, 4176)
# 50ugserum_noMP_INCL_5ul240run_Subj1_inj1-s1.mzML
# (1.003, 6598.19, 350.0342712402344, 1998.6015625, 2492)
# 50ugserum_noMP_INCL_5ul240run_Subj3_inj1-s1.mzML
# (1.001, 6599.56, 350.0395812988281, 1997.659912109375, 2757)
# 50ugserum_noMP_INCL_5ul240run_Subj4_inj1-s1.mzML
# (1.005, 6599.32, 350.0342712402344, 1997.1109619140625, 2969)
# 50ugserum_MPrep_INCL_5ul240run_Subj2_inj1-s1.mzML
# (1.0, 6599.08, 350.0295715332031, 1998.1787109375, 3876)
# 50ugserum_MPrep_INCL_5ul240run_Subj5_inj1-s1.mzML
# (1.003, 6599.35, 350.02252197265625, 1995.9580078125, 4171)
# 50ugserum_noMP_INCL_5ul240run_Subj5_inj1-s1.mzML
# (1.0, 6599.71, 350.0172119140625, 1999.2430419921875, 4362)
# 50ugserum_noMP_INCL_5ul240run_Subj2_inj1-s1.mzML
# (1.001, 6598.29, 350.0360412597656, 1998.5889892578125, 2648)
# ...

# %%
RT_the_whole =[]
exp = MSExperiment()
MzMLFile().load(files[0], exp)
# mg = np.zeros((10, 4000))
count =0
RT =[]
X =[]
# for  count, spec in enumerate(exp):
#     f spec.getMSLevel()==1:
#     RT.append([count,spec.getRT()])
#     print(spec.getRT(), spec.getMSLevel(), count)

# %%
# ind = 906
# mz,intensity = exp[ind].get_peaks()
# print(mz)
# mz,intensity = exp[ind+1].get_peaks()
# print(mz)
# plt.figure()
# plt.plot(intensity)
# mz,intensity = exp[ind+2].get_peaks()
# print(mz)
# plt.figure()
# plt.plot(intensity)
# mz,intensity = exp[ind+3].get_peaks()
# print(mz)
# plt.figure()
# plt.plot(intensity)
# mz,intensity = exp[ind+4].get_peaks()
# print(mz)
# plt.figure()
# plt.plot(intensity)
# mz,intensity = exp[ind+5].get_peaks()
# print(mz)
# plt.figure()
# plt.plot(intensity)
# mz,intensity = exp[ind+6].get_peaks()
# print(mz)
# plt.figure()
# plt.plot(intensity)

# %%
np.shape(RT_the_whole1)
# Out:
# (4520,)

# %%
# uniqueValues, occurCount = numpy.unique(RT, return_counts=True)
 
# # print("Unique Values : " , uniqueValues[1007:2000])
# print("Occurrence Count : ", occurCount[1007:2000])

# %%
# for count,spec in enumerate(exp):
#     print ("MS Level:", (count,spec.getMSLevel()))

# %%
# ts=int(4*60/7)
# te = int(8*60/7)
# mz = 501.25
# rate = 4
def plot_spike_contrast(ts,te, mz, rate, ylim):

    ts=int(ts*60)
    te = int(te*60)
    
    mz = mz
    rate = rate
    fig , (ax1,ax2) = plt.subplots(1,2, figsize = ( 9,3))
#     plt.figure()
    ax1.set_title('mz='+str(mz)+ '(MP)')
    ax1.set(xlabel='RT', ylabel= 'Intensity')
#     ax1.ylabel('Intensity')
    ax1.set_ylim(top=ylim)
    for image, RT in zip (Images_mp, RT_mp):
        xmin= int(np.floor( RT[find_nearest(RT,ts)]/10 ))
        xmax= int(np.floor( RT[find_nearest(RT,te)]/10 ))
        ax1.plot(range(xmin,xmax),\
             image[xmin:xmax,int(round_of_rating(mz,rate)*rate)-600])
#         ax1.set_xticks(np.arange(xmin,xmax,2), np.arange(xmin*7,xmax*7, step=np.size(np.arange(xmin,xmax,2))) )

#     plt.figure()
    ax2.set_title('mz='+str(mz)+ '(noMP)')
    ax2.set(xlabel='RT', ylabel= 'Intensity')
#     ax2.ylabel('Intensity')
    ax2.set_ylim(top=ylim)
    for image, RT in zip (Images_nomp, RT_nomp):
        xmin= int(np.floor( RT[find_nearest(RT,ts)]/10 ))
        xmax= int(np.floor( RT[find_nearest(RT,te)]/10 ))
        ax2.plot(range(xmin,xmax),\
             image[xmin:xmax,int(round_of_rating(mz,rate)*rate)-600])
#     plt.savefig('Visualize_peaks/'+str(mz)+'.png')

# %%
rate=2
plot_spike_contrast(ts=4, te=8, mz=501.25, rate=rate , ylim= 200)
plot_spike_contrast(ts=45, te=49, mz=450.23, rate=rate, ylim= 1000)
plot_spike_contrast(ts=53, te=56, mz=530.78, rate=rate , ylim= 4000)
plot_spike_contrast(ts=53, te=56, mz=354.19, rate=rate , ylim= 1000)
plot_spike_contrast(ts=59, te=62, mz=523.77, rate=rate , ylim= 2000)
plot_spike_contrast(ts=63 , te=67, mz= 648.84, rate=rate , ylim= 400)
plot_spike_contrast(ts=63 , te=67, mz= 432.89, rate=rate , ylim= 2000)
plot_spike_contrast(ts=74, te=77, mz= 586.98 , rate=rate , ylim= 100)
plot_spike_contrast(ts=82 , te=86, mz= 630.35, rate=rate , ylim= 100)
plot_spike_contrast(ts=80 , te=83, mz= 943.43, rate=rate , ylim= 100)
plot_spike_contrast(ts=77 , te=81, mz= 624.995, rate=rate , ylim= 200)
plot_spike_contrast(ts=82 , te=86, mz= 630.35, rate=rate , ylim= 200)
plot_spike_contrast(ts=104 , te=106, mz= 712.43, rate=rate , ylim= 100)
plot_spike_contrast(ts=104 , te=106, mz= 570.15, rate=rate , ylim= 200)

# %%
ind = np.unravel_index(np.argmax(image1, axis=None), image1.shape)
ind
# Out:
# (48, 2220)

# %%
RT_the_whole1[find_nearest(RT_the_whole1,2700)]
# Out:
# 2698.94

# %%
# MZ_unique = np.unique( [item for sublist in MZ for item in sublist])
# np.shape(MZ_unique)
plt.figure(figsize=(10,20))
plt.imshow(Images_nomp[1],cmap="seismic", vmin=-500,vmax=500)
plt.xticks(np.arange(0, 4000, step=200), np.arange(0, 1000, step=50))
plt.yticks(np.arange(0, 1000, step=200), np.arange(0, 125, step=25))
plt.xlabel('m/z ')
plt.ylabel('RT(min)')
plt.title('no-MP')
plt.savefig('Images-noMP.png')

# %%
plt.figure(figsize=(10,20))
plt.imshow(Images_mp[1],cmap="seismic", vmin=-500,vmax=500)
plt.xticks(np.arange(0, 4000, step=200), np.arange(0, 1000, step=50))
plt.yticks(np.arange(0, 1000, step=200), np.arange(0, 125, step=25))
plt.xlabel('m/z ')
plt.ylabel('RT(min)')
plt.title('MP')
plt.savefig('Images-MP.png')

# %%
plt.figure(figsize=(10,20))
plt.imshow(abs(Images_mp[1]-Images_nomp[1]),cmap="seismic", clim=(-100,100))
plt.xticks(np.arange(0, 4000, step=200), np.arange(0, 1000, step=50))
plt.xlabel('m/z')
plt.ylabel('RT')
plt.title('diff')
# Out:
# Text(0.5, 1.0, 'diff')
